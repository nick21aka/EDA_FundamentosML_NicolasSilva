# %% [markdown]
# <a href="https://colab.research.google.com/github/nick21aka/EDA_FundamentosML_NicolasSilva/blob/main/PRUEBA1NICOLASSILVA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = '/content/drive/MyDrive/WA_Fn-UseC_-HR-Employee-Attrition.csv'
basedatos = pd.read_csv(url, sep=",", encoding='utf-8')

# %%
basedatos.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Comparación de satisfacción laboral, ingreso y antigüedad según rotación
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Satisfacción laboral vs Attrition
sns.boxplot(x="Attrition", y="JobSatisfaction", data=df, palette="coolwarm", ax=axes[0])
axes[0].set_title("Satisfacción Laboral vs. Rotación")

# Ingreso mensual vs Attrition
sns.boxplot(x="Attrition", y="MonthlyIncome", data=df, palette="coolwarm", ax=axes[1])
axes[1].set_title("Ingreso Mensual vs. Rotación")

# Años en la empresa vs Attrition
sns.boxplot(x="Attrition", y="YearsAtCompany", data=df, palette="coolwarm", ax=axes[2])
axes[2].set_title("Años en la Empresa vs. Rotación")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-50-eb3e927d9be2>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Attrition", y="JobSatisfaction", data=df, palette="coolwarm", ax=axes[0])
# <ipython-input-50-eb3e927d9be2>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Attrition", y="MonthlyIncome", data=df, palette="coolwarm", ax=axes[1])
# <ipython-input-50-eb3e927d9be2>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Attrition", y="YearsAtCompany", data=df, palette="coolwarm", ax=axes[2])

# %% [markdown]
# LOS EMPLEADOS CON MENORES INGRESOS TIENDEN ABANDONAR LA EMPRESA CON MAS FRECUENCIA. ESTO DEBIDO A QUE GRACIAS AL SEGUNDO GRAFICO BOXPLOT DONDE REPRESENTA EL NIVEL DE INGRESO MENSUAL DE LOS EMPLEADOS SEGUN SU ESTADO DE ROTACION, LOS BIGOTES INDICAN LA DISPERSION DE LOS DATOS DENTRO DE 1.5 VECES EL IQR.
# EL ANALISIS DESCRIBE QUE LOS EMPLEADOS QUE SE QUEDAN EN LA EMPRESA TIENEN UN MAYOR INGRESO EN COMPARACION CON LOS QUE SE VAN.
#
# LA ROTACION DE LOS EMPLEADOS ESTA CARACTERIZADA POR FACTORES ECONOMICOS, SATISFACCION LABORAL, CARGA DE TRABAJO Y ANTIGUEDAD.

# %%
import pandas as pd
import numpy as np
# Select only numeric columns before calculating the mean
numeric_basedatos = basedatos.select_dtypes(include=np.number)
basedatos_mean = numeric_basedatos.mean()
print(basedatos_mean)
# Out:
# Age                            36.923810
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1024.865306
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyIncome                6502.931293
# MonthlyRate                 14313.103401
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.209524
# PerformanceRating               3.153741
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# ...

# %% [markdown]
# # Nueva sección

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Contar la distribución de la variable Attrition
attrition_counts = df["Attrition"].value_counts(normalize=True) * 100

# Gráfico de la distribución de la rotación de empleados
plt.figure(figsize=(6,4))
sns.barplot(x=attrition_counts.index, y=attrition_counts.values, palette="coolwarm")
plt.ylabel("Porcentaje")
plt.title("Distribución de la Rotación de Personal (Attrition)")
plt.ylim(0, 100)
plt.show()

# Mostrar los porcentajes
attrition_counts
# Out:
# <ipython-input-23-5b1aa98f72d5>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=attrition_counts.index, y=attrition_counts.values, palette="coolwarm")
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %% [markdown]
# EL GRAFICO REPRESENTA QUE EL 16% DE LOS EMPLEADOS HAN DECIDIDO DEJAR LA EMPRESA MIENTRAS QUE EL 83.9% HA DECIDIDO QUEDARSE.
